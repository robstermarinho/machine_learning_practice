# %%
import sys
print(sys.version)
# Out:
# 3.6.2 |Anaconda, Inc.| (default, Sep 19 2017, 08:03:39) [MSC v.1900 64 bit (AMD64)]

# %%
import platform
platform.python_version()
# Out:
# '3.6.2'

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
import sklearn

# %%
# Load the data

# Thousands with comma signals = ','
oecd_bli = pd.read_csv("data\oecd_bli_2015.csv", thousands=",")

# %%
# Print 5 fisrt results
oecd_bli.head(120)
# Out:
#     LOCATION          Country INDICATOR                           Indicator  \
# 0        AUS        Australia   HO_BASE  Dwellings without basic facilities
# 1        AUT          Austria   HO_BASE  Dwellings without basic facilities
# 2        BEL          Belgium   HO_BASE  Dwellings without basic facilities
# 3        CAN           Canada   HO_BASE  Dwellings without basic facilities
# 4        CZE   Czech Republic   HO_BASE  Dwellings without basic facilities
# 5        DNK          Denmark   HO_BASE  Dwellings without basic facilities
# 6        FIN          Finland   HO_BASE  Dwellings without basic facilities
# 7        FRA           France   HO_BASE  Dwellings without basic facilities
# 8        DEU          Germany   HO_BASE  Dwellings without basic facilities
# 9        GRC           Greece   HO_BASE  Dwellings without basic facilities
# 10       HUN          Hungary   HO_BASE  Dwellings without basic facilities
# ...

# %%
# Get info of nulls or non-nulls rows
oecd_bli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3292 entries, 0 to 3291
# Data columns (total 17 columns):
# LOCATION                 3292 non-null object
# Country                  3292 non-null object
# INDICATOR                3292 non-null object
# Indicator                3292 non-null object
# MEASURE                  3292 non-null object
# Measure                  3292 non-null object
# INEQUALITY               3292 non-null object
# Inequality               3292 non-null object
# Unit Code                3292 non-null object
# Unit                     3292 non-null object
# PowerCode Code           3292 non-null int64
# PowerCode                3292 non-null object
# Reference Period Code    0 non-null float64
# Reference Period         0 non-null float64
# Value                    3292 non-null float64
# Flag Codes               1120 non-null object
# Flags                    1120 non-null object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 437.3+ KB

# %%
# Number of rows and collums
oecd_bli.shape
# Out:
# (3292, 17)

# %%
# The other parameter tells about features of the csv file
gdp_per_capta = pd.read_csv("data/gdp_per_capita.csv", thousands=",", delimiter="\t", encoding="latin1", na_values="n/a")
# 10 first records
gdp_per_capta.head(10)
# Out:
#                Country                                 Subject Descriptor  \
# 0          Afghanistan  Gross domestic product per capita, current prices
# 1              Albania  Gross domestic product per capita, current prices
# 2              Algeria  Gross domestic product per capita, current prices
# 3               Angola  Gross domestic product per capita, current prices
# 4  Antigua and Barbuda  Gross domestic product per capita, current prices
# 5            Argentina  Gross domestic product per capita, current prices
# 6              Armenia  Gross domestic product per capita, current prices
# 7            Australia  Gross domestic product per capita, current prices
# 8              Austria  Gross domestic product per capita, current prices
# 9           Azerbaijan  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# ...

# %%
# 10 last records
gdp_per_capta.tail(10)
# Out:
#                                                Country  \
# 180                                      United States
# 181                                            Uruguay
# 182                                         Uzbekistan
# 183                                            Vanuatu
# 184                                          Venezuela
# 185                                            Vietnam
# 186                                              Yemen
# 187                                             Zambia
# 188                                           Zimbabwe
# 189  International Monetary Fund, World Economic Ou...
#
#                                     Subject Descriptor         Units  Scale  \
# 180  Gross domestic product per capita, current prices  U.S. dollars  Units
# 181  Gross domestic product per capita, current prices  U.S. dollars  Units
# 182  Gross domestic product per capita, current prices  U.S. dollars  Units
# ...

# %%
gdp_per_capta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 7 columns):
# Country                          190 non-null object
# Subject Descriptor               189 non-null object
# Units                            189 non-null object
# Scale                            189 non-null object
# Country/Series-specific Notes    188 non-null object
# 2015                             187 non-null float64
# Estimates Start After            188 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 10.5+ KB

# %%
# I want to know the relation between life satisfaction and GDP of the country
# Richness brings happiness?
